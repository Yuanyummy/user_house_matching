# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from tqdm.notebook import tqdm
from torch.utils.tensorboard import SummaryWriter  # Import the tensorboard writer
import numpy as np

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # load user data

# %%
answer_sheet = '../samples/demo_houses/user_features.csv'
df_user = pd.read_csv(answer_sheet).drop(columns='Unnamed: 0')
print(df_user.shape[0])
df_user.userGender = df_user.userGender - 1 # avoid index error
# print(df_user.userAgeIds.unique())
df_user.head()
print(sum(df_user.Q1 == 0))
# Out:
# 3800
# 657

# %% [markdown]
# # start to encode the user attr

# %%
num_unique_ids = {
    'userGender': 2,
    'userAgeIds': df_user.userAgeIds.max() + 1,
    'userPrefectureIds': df_user.userPrefectureIds.nunique(),
}

embedding_fn = {
    'userGender': nn.Embedding(num_embeddings=num_unique_ids['userGender'], embedding_dim=min(50, int(num_unique_ids['userGender']/2))),
    'userAgeIds': nn.Embedding(num_embeddings=num_unique_ids['userAgeIds'], embedding_dim=min(50, int(num_unique_ids['userAgeIds']/2))),
    'userPrefectureIds': nn.Embedding(num_embeddings=num_unique_ids['userPrefectureIds'], embedding_dim=min(50, int(num_unique_ids['userPrefectureIds']/2))),
}
print(num_unique_ids)
print(embedding_fn)
# Out:
# {'userGender': 2, 'userAgeIds': 15, 'userPrefectureIds': 48}
# {'userGender': Embedding(2, 1), 'userAgeIds': Embedding(15, 7), 'userPrefectureIds': Embedding(48, 24)}

# %%
user_data_dict= {
    'userGender':  torch.LongTensor(df_user['userGender'].values).unsqueeze(1),
    'userAgeIds':  torch.LongTensor(df_user['userAgeIds'].values).unsqueeze(1),
    'userPrefectureIds': torch.LongTensor(df_user['userPrefectureIds'].values).unsqueeze(1),
}
print(user_data_dict['userGender'].shape)
# Out:
# torch.Size([3800, 1])

# %%
# label_encoder = LabelEncoder()
# df_user['Q_label'] = label_encoder.fit_transform(df_user['Q1'])
# Q_labels = torch.tensor(df_user['Q_label'].values)
# print(Q_labels)
Q_labels = torch.tensor(df_user['Q1'].values * 2).float() # *2 to turn -1 ~1 to -2 ~2 as it is cosine diff
print(Q_labels.dtype)
# Out:
# torch.float32

# %% [markdown]
# # define model to calculate the representation for user and images

# %%
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=2):
        super(MLP, self).__init__()
        self.layers = nn.ModuleList()
        
        # Add the first layer
        self.layers.append(nn.Linear(input_size, hidden_size))
        
        # Add hidden layers
        for _ in range(n_layers - 2):
            self.layers.append(nn.Linear(hidden_size, hidden_size))
        
        # Add the output layer
        self.layers.append(nn.Linear(hidden_size, output_size))
    def forward(self, x):
        # Apply ReLU to all layers except the last one
        for layer in self.layers[:-1]:
            x = F.relu(layer(x))
        
        # Output layer without ReLU
        x = self.layers[-1](x)
        return x

# %%
class UserAttributeEmbeddings(nn.Module):
    def __init__(self, embedding_fn):
        super(UserAttributeEmbeddings, self).__init__()
        self.embedding_userGender = embedding_fn['userGender']
        self.embedding_userAgeIds = embedding_fn['userAgeIds']
        self.embedding_userPrefectureIds =  embedding_fn['userPrefectureIds']
        self.output_dim = self.embedding_userGender.embedding_dim + self.embedding_userAgeIds.embedding_dim + self.embedding_userPrefectureIds.embedding_dim
    def forward(self, userGender, userAgeIds , userPrefectureIds):
        embedded_userGender = self.embedding_userGender(userGender).squeeze(dim=0)
        embedded_userAgeIds = self.embedding_userAgeIds(userAgeIds).squeeze(dim=0)
        embedded_userPrefectureIds = self.embedding_userPrefectureIds(userPrefectureIds).squeeze(dim=0)
        # Concatenate embeddings along the last dimension
        # print('!!!embed shape userAgeIds', embedded_userAgeIds.shape)
        return torch.cat((embedded_userGender, embedded_userAgeIds, embedded_userPrefectureIds), dim=-1)

# %%
# image user sim model
class ImageUserSimilarityModel(nn.Module):
    def __init__(self, image_feature_size, embedding_fn, hidden_size, output_size, user_n_layer=2, image_n_layer=2):
        super(ImageUserSimilarityModel, self).__init__()
        self.image_mlp = MLP(image_feature_size, hidden_size, output_size, n_layers=image_n_layer )
        self.user_embeddings = UserAttributeEmbeddings(embedding_fn)
        # Adjust the MLP input size to three times the embedding size (for three concatenated embeddings)
        self.user_mlp = MLP(self.user_embeddings.output_dim, hidden_size, output_size, n_layers=user_n_layer)

    def forward(self, image_features,  userGender, userAgeIds , userPrefectureIds):
        # Process image features, expected shape should be (bs, 768)
        image_output = self.image_mlp(image_features)

        # Process user attributes, expected shape should be (bs, 1)
        user_embedded = self.user_embeddings(userGender, userAgeIds , userPrefectureIds)
        # print('user_embed dim', user_embedded.shape)
        user_output = self.user_mlp(user_embedded).squeeze(1)
        # print('image repr dim', image_output.shape, 'user repr dim', user_output.shape)
        
        # Normalize the outputs
        # print(image_output.shape, user_output.shape)
        image_output = F.normalize(image_output, p=2, dim=1)
        user_output = F.normalize(user_output, p=2, dim=1)

        # Compute cosine similarity
        similarity = (image_output * user_output).sum(dim=1)
        return similarity

# %% [markdown]
# # test the model using single image and user attributes

# %%
## instantialize
image_user_sim_model = ImageUserSimilarityModel(image_feature_size=768, embedding_fn=embedding_fn, hidden_size=768, output_size=128)
image_user_sim_model.to(device)

def print_trainable_parameters(model):
    for name, param in model.named_parameters():
        if param.requires_grad:
            print(f"Parameter name: {name}, Shape: {param.size()}")
    total_params = sum(p.numel() for p in image_user_sim_model.parameters() if p.requires_grad)
    print(f"Total trainable parameters: {total_params}")
    # print(model.user_embeddings.output_dim)
print_trainable_parameters(image_user_sim_model)
# Out:
# Parameter name: image_mlp.layers.0.weight, Shape: torch.Size([768, 768])
# Parameter name: image_mlp.layers.0.bias, Shape: torch.Size([768])
# Parameter name: image_mlp.layers.1.weight, Shape: torch.Size([128, 768])
# Parameter name: image_mlp.layers.1.bias, Shape: torch.Size([128])
# Parameter name: user_embeddings.embedding_userGender.weight, Shape: torch.Size([2, 1])
# Parameter name: user_embeddings.embedding_userAgeIds.weight, Shape: torch.Size([15, 7])
# Parameter name: user_embeddings.embedding_userPrefectureIds.weight, Shape: torch.Size([48, 24])
# Parameter name: user_mlp.layers.0.weight, Shape: torch.Size([768, 32])
# Parameter name: user_mlp.layers.0.bias, Shape: torch.Size([768])
# Parameter name: user_mlp.layers.1.weight, Shape: torch.Size([128, 768])
# Parameter name: user_mlp.layers.1.bias, Shape: torch.Size([128])
# Total trainable parameters: 814059

# %%
test_image_feature = torch.load('../features_from_samples_ly/image_feature/image_embeds_A_105_0.pt')
print(test_image_feature.shape)

test_userGender = user_data_dict['userGender'][0:1]# .unsqueeze(1)
test_userAgeIds = user_data_dict['userAgeIds'][0:1]# .unsqueeze(1)
test_userPrefectureIds = user_data_dict['userPrefectureIds'][0:1]# .unsqueeze(1)
print(test_userGender, test_userAgeIds, test_userPrefectureIds)
# Out:
# torch.Size([1, 768])
# tensor([[0]]) tensor([[9]]) tensor([[0]])

# %%
sim = image_user_sim_model(test_image_feature.to(device), test_userGender.to(device), test_userAgeIds.to(device), test_userPrefectureIds.to(device))
print(sim)
print(sim.shape)
# Out:
# tensor([-0.0766], device='cuda:0', grad_fn=<SumBackward1>)
# torch.Size([1])

# %% [markdown]
# # construct dataset and training loop

# %%
class ImageUserDataset(Dataset):
    def __init__(self, image_features_A, image_features_B, user_data_dict, Q_labels):
        """
        Args:
            image_features_A or B (Tensor): image tensor representations
            user_data_dict (dict): dict for userGender, userAgeIds, userPrefectureIds
        """
        self.image_features_A = image_features_A
        self.image_features_B = image_features_B
        self.user_data_dict = user_data_dict
        self.userGender = self.user_data_dict['userGender']
        self.userAgeIds = self.user_data_dict['userAgeIds']
        self.userPrefectureIds = self.user_data_dict['userPrefectureIds']
        self.labels = Q_labels
        assert len(self.image_features_A) == len(self.userGender), 'warning: user length and image feature mismatch!'

    def __len__(self):
        return len(self.image_features_A)

    def __getitem__(self, index):
        # Fetch the data and label at the specified index
        image_feature_A = self.image_features_A[index]
        image_feature_B = self.image_features_B[index]
        userGender, userAgeIds, userPrefectureIds = self.userGender[index], self.userAgeIds[index], self.userPrefectureIds[index]
        label = self.labels[index]
        return image_feature_A, image_feature_B,  userGender, userAgeIds, userPrefectureIds, label

# %%
def calculate_sign_agreement_ignoring_zero(outputs, targets):
    # Identify non-zero indices in both outputs and targets
    non_zero_mask = (outputs != 0) & (targets != 0)
    
    # Filter outputs and targets to remove zeros
    filtered_outputs = outputs[non_zero_mask]
    filtered_targets = targets[non_zero_mask]

    # Calculate signs and agreement on non-zero elements only
    sign_outputs = torch.sign(filtered_outputs)
    sign_targets = torch.sign(filtered_targets)
    # agreement = sign_outputs == sign_targets
    # print(len(sign_outputs))
    return sign_outputs, sign_targets
    
# Example outputs and true labels
outputs = torch.tensor([[-3.5], [0.0], [3.0], [-1.0]])  # Shape (4, 1)
targets = torch.tensor([[-1], [1], [1], [-1]])  # Shape (4, 1)

# Calculate sign agreement accuracy
sign_outputs, sign_targets = calculate_sign_agreement_ignoring_zero(outputs, targets)
print("Sign Agreement:", sign_outputs, sign_targets)
# Out:
# Sign Agreement: tensor([-1.,  1., -1.]) tensor([-1,  1, -1])

# %%
# prepare image A B dataset
image_A_data = []
for image_id in tqdm(df_user.Afilename):
    tensor = torch.load(f'../features_from_samples_ly/image_feature/image_embeds_{image_id}_all.pt')
    image_A_data.append(tensor)
image_A_features = torch.cat(image_A_data, dim=0)
print(image_A_features.shape)
# Out:
#   0%|          | 0/3800 [00:00<?, ?it/s]
# torch.Size([3800, 768])

# %%
image_B_data = []
for image_id in tqdm(df_user.Bfilename):
    tensor = torch.load(f'../features_from_samples_ly/image_feature/image_embeds_{image_id}_all.pt')
    image_B_data.append(tensor)
image_B_features = torch.cat(image_B_data, dim=0)
print(image_B_features.shape)
# Out:
#   0%|          | 0/3800 [00:00<?, ?it/s]
# torch.Size([3800, 768])

# %% [markdown]
# # create image-user dataset

# %%
image_user_dataset = ImageUserDataset(image_A_features, image_B_features, user_data_dict, Q_labels)
# image_user_dataset[0]

# %%
# Split the dataset into train and validation sets
train_size = int(0.8 * len(image_user_dataset))
test_size = len(image_user_dataset) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(image_user_dataset, [train_size, test_size])
print(len(train_dataset), len(test_dataset))
# Out:
# 3040 760

# %% [markdown]
# # training loop!!

# %%
batch_size = 128
n_epoch = 500
lr = 5e-6

hidden_size = 32
output_size = 32

## instantialize
image_user_sim_model = ImageUserSimilarityModel(image_feature_size=768, 
                                                embedding_fn=embedding_fn, 
                                                hidden_size=hidden_size, 
                                                output_size=output_size,
                                                image_n_layer=4,
                                                user_n_layer=4
                                               )
image_user_sim_model.to(device)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(image_user_sim_model.parameters(), lr=lr)

writer = SummaryWriter('runs/my_experiment')
print_trainable_parameters(image_user_sim_model)
# dataset output: image_feature_A, image_feature_B,  userGender, userAgeIds, userPrefectureIds, label
from sklearn.metrics import f1_score

def train_model(model, train_loader, validation_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        predictions = []
        true_labels = []
        for i, (batch_imageA_features, batch_imageB_features, batch_userGender, batch_userAgeIds, batch_userPrefectureIds, batch_labels) in enumerate(train_loader, 0):
            optimizer.zero_grad()
            # print(batch_imageA_features.shape, batch_userGender.shape)
            # forward + backward + optimize
            sim_A = model(
                batch_imageA_features.to(device), 
                batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
            )
            sim_B = model(
                batch_imageB_features.to(device), 
                batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
            )
            
            # print('sim_A', sim_A, sim_A.shape)
            batch_score_diff = sim_B - sim_A # -1 prefer A, +1 prefer B, so score > 0 means B better, diff = B -A 
            # print(batch_score_diff.shape)
            batch_score_diff = batch_score_diff.squeeze()
            # print(batch_score_diff.dtype, batch_labels.dtype)
            loss = criterion(batch_score_diff, batch_labels.float().to(device))
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            sign_outputs, sign_targets = calculate_sign_agreement_ignoring_zero(batch_score_diff.detach().cpu(), batch_labels)

            predictions.extend(sign_outputs.detach().cpu().numpy())    
            true_labels.extend(sign_targets.detach().cpu().numpy())
            
            total += sign_targets.size(0)
            correct += (sign_outputs == sign_targets).sum().item()

        train_accuracy = 100 * correct / total
        predictions = np.array(predictions)
        true_labels = np.array(true_labels)
        train_f1_score = f1_score(true_labels, predictions, average='macro') * 100
        train_loss = running_loss / len(train_loader)
        # train_accuracy = 100 * correct / total

        # Log training loss and accuracy
        writer.add_scalar('Loss/train', train_loss, epoch)
        writer.add_scalar('Accuracy/train', train_accuracy, epoch)
        writer.add_scalar('F1-Score/train', train_f1_score, epoch)
        # Validation loss
        model.eval()
        running_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            predictions = []
            true_labels = []
            for i, (batch_imageA_features, batch_imageB_features, batch_userGender, batch_userAgeIds, batch_userPrefectureIds, batch_labels) in enumerate(validation_loader, 0):
                sim_A = model(
                    batch_imageA_features.to(device), 
                    batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
                )
                sim_B = model(
                    batch_imageB_features.to(device), 
                    batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
                )
                batch_score_diff = sim_B - sim_A # -1 prefer A, +1 prefer B, so score > 0 means B better, diff = B -A 
                batch_score_diff = batch_score_diff.squeeze()
                loss = criterion(batch_score_diff, batch_labels.float().to(device))
                running_loss += loss.item()
                
                
                sign_outputs, sign_targets = calculate_sign_agreement_ignoring_zero(batch_score_diff.detach().cpu(), batch_labels)

                predictions.extend(sign_outputs.detach().cpu().numpy())    
                true_labels.extend(sign_targets.detach().cpu().numpy())
                # target = categorize_scores(batch_labels)
                total += sign_targets.size(0)
                correct += (sign_outputs == sign_targets).sum().item()

        valid_loss = running_loss / len(validation_loader)
        valid_accuracy = 100 * correct / total
        predictions = np.array(predictions)
        true_labels = np.array(true_labels)
        val_f1_score = f1_score(true_labels, predictions, average='macro') * 100

        # Log validation loss and accuracy
        writer.add_scalar('Loss/validation', valid_loss, epoch)
        writer.add_scalar('Accuracy/validation', valid_accuracy, epoch)
        writer.add_scalar('F1-Score/validation', val_f1_score, epoch)

        print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, train acc: {train_accuracy:.4f}, train F1: {train_f1_score:.4f}', 
              f'Val Loss: {valid_loss:.4f}, valid acc: {valid_accuracy:.4f}, valid F1: {val_f1_score:.4f}')

    print('Finished Training')
    writer.close()

# Assuming train_loader and validation_loader are defined
train_model(image_user_sim_model, train_loader, test_loader, criterion, optimizer, epochs=n_epoch)
# Out:
# Parameter name: image_mlp.layers.0.weight, Shape: torch.Size([32, 768])
# Parameter name: image_mlp.layers.0.bias, Shape: torch.Size([32])
# Parameter name: image_mlp.layers.1.weight, Shape: torch.Size([32, 32])
# Parameter name: image_mlp.layers.1.bias, Shape: torch.Size([32])
# Parameter name: image_mlp.layers.2.weight, Shape: torch.Size([32, 32])
# Parameter name: image_mlp.layers.2.bias, Shape: torch.Size([32])
# Parameter name: image_mlp.layers.3.weight, Shape: torch.Size([32, 32])
# Parameter name: image_mlp.layers.3.bias, Shape: torch.Size([32])
# Parameter name: user_embeddings.embedding_userGender.weight, Shape: torch.Size([2, 1])
# Parameter name: user_embeddings.embedding_userAgeIds.weight, Shape: torch.Size([15, 7])
# Parameter name: user_embeddings.embedding_userPrefectureIds.weight, Shape: torch.Size([48, 24])
# Parameter name: user_mlp.layers.0.weight, Shape: torch.Size([32, 32])
# Parameter name: user_mlp.layers.0.bias, Shape: torch.Size([32])
# Parameter name: user_mlp.layers.1.weight, Shape: torch.Size([32, 32])
# Parameter name: user_mlp.layers.1.bias, Shape: torch.Size([32])
# Parameter name: user_mlp.layers.2.weight, Shape: torch.Size([32, 32])
# Parameter name: user_mlp.layers.2.bias, Shape: torch.Size([32])
# Parameter name: user_mlp.layers.3.weight, Shape: torch.Size([32, 32])
# Parameter name: user_mlp.layers.3.bias, Shape: torch.Size([32])
# Total trainable parameters: 33259
# Epoch 1, Train Loss: 1.4974, train acc: 49.8006, train F1: 49.7765 Val Loss: 1.6127, valid acc: 51.0236, valid F1: 51.0217
# Epoch 2, Train Loss: 1.4953, train acc: 51.5550, train F1: 51.5244 Val Loss: 1.6105, valid acc: 52.1260, valid F1: 52.1259
# Epoch 3, Train Loss: 1.4935, train acc: 53.0702, train F1: 53.0259 Val Loss: 1.6086, valid acc: 52.5984, valid F1: 52.5980
# Epoch 4, Train Loss: 1.4920, train acc: 53.6683, train F1: 53.6137 Val Loss: 1.6068, valid acc: 53.0709, valid F1: 53.0707
# Epoch 5, Train Loss: 1.4905, train acc: 54.2663, train F1: 54.2209 Val Loss: 1.6049, valid acc: 53.5433, valid F1: 53.5415
# Epoch 6, Train Loss: 1.4892, train acc: 54.7448, train F1: 54.7021 Val Loss: 1.6032, valid acc: 53.3858, valid F1: 53.3848
# Epoch 7, Train Loss: 1.4878, train acc: 55.0239, train F1: 54.9659 Val Loss: 1.6017, valid acc: 54.1732, valid F1: 54.1728
# Epoch 8, Train Loss: 1.4865, train acc: 55.5024, train F1: 55.4398 Val Loss: 1.6003, valid acc: 54.8031, valid F1: 54.8027
# Epoch 9, Train Loss: 1.4852, train acc: 55.8214, train F1: 55.7482 Val Loss: 1.5988, valid acc: 55.7480, valid F1: 55.7410
# Epoch 10, Train Loss: 1.4838, train acc: 56.0207, train F1: 55.9405 Val Loss: 1.5973, valid acc: 56.8504, valid F1: 56.8374
# Epoch 11, Train Loss: 1.4824, train acc: 57.0175, train F1: 56.9317 Val Loss: 1.5957, valid acc: 57.6378, valid F1: 57.6273
# Epoch 12, Train Loss: 1.4808, train acc: 58.0144, train F1: 57.9320 Val Loss: 1.5937, valid acc: 58.8976, valid F1: 58.8960
# Epoch 13, Train Loss: 1.4791, train acc: 58.4928, train F1: 58.4171 Val Loss: 1.5917, valid acc: 60.1575, valid F1: 60.1512
# Epoch 14, Train Loss: 1.4774, train acc: 59.1308, train F1: 59.0563 Val Loss: 1.5898, valid acc: 60.7874, valid F1: 60.7734
# Epoch 15, Train Loss: 1.4759, train acc: 59.4896, train F1: 59.4277 Val Loss: 1.5880, valid acc: 61.7323, valid F1: 61.7137
# Epoch 16, Train Loss: 1.4744, train acc: 59.8485, train F1: 59.7833 Val Loss: 1.5861, valid acc: 61.5748, valid F1: 61.5533
# Epoch 17, Train Loss: 1.4729, train acc: 60.1675, train F1: 60.0806 Val Loss: 1.5843, valid acc: 61.8898, valid F1: 61.8783
# Epoch 18, Train Loss: 1.4713, train acc: 60.6858, train F1: 60.5863 Val Loss: 1.5823, valid acc: 62.5197, valid F1: 62.5084
# Epoch 19, Train Loss: 1.4697, train acc: 61.0048, train F1: 60.8965 Val Loss: 1.5803, valid acc: 62.3622, valid F1: 62.3488
# Epoch 20, Train Loss: 1.4680, train acc: 61.1244, train F1: 61.0213 Val Loss: 1.5784, valid acc: 62.0472, valid F1: 62.0439
# Epoch 21, Train Loss: 1.4664, train acc: 61.0447, train F1: 60.9507 Val Loss: 1.5763, valid acc: 61.7323, valid F1: 61.7308
# Epoch 22, Train Loss: 1.4648, train acc: 61.2440, train F1: 61.1693 Val Loss: 1.5743, valid acc: 61.8898, valid F1: 61.8889
# Epoch 23, Train Loss: 1.4632, train acc: 61.2041, train F1: 61.1307 Val Loss: 1.5723, valid acc: 62.6772, valid F1: 62.6768
# Epoch 24, Train Loss: 1.4616, train acc: 61.4035, train F1: 61.3396 Val Loss: 1.5702, valid acc: 62.6772, valid F1: 62.6768
# Epoch 25, Train Loss: 1.4599, train acc: 61.5231, train F1: 61.4655 Val Loss: 1.5681, valid acc: 62.6772, valid F1: 62.6768
# Epoch 26, Train Loss: 1.4582, train acc: 61.6826, train F1: 61.6406 Val Loss: 1.5658, valid acc: 62.6772, valid F1: 62.6738
# Epoch 27, Train Loss: 1.4563, train acc: 61.8022, train F1: 61.7633 Val Loss: 1.5632, valid acc: 62.9921, valid F1: 62.9863
# Epoch 28, Train Loss: 1.4543, train acc: 61.8022, train F1: 61.7725 Val Loss: 1.5604, valid acc: 62.6772, valid F1: 62.6679
# Epoch 29, Train Loss: 1.4522, train acc: 61.6826, train F1: 61.6614 Val Loss: 1.5577, valid acc: 62.6772, valid F1: 62.6638
# Epoch 30, Train Loss: 1.4499, train acc: 61.9219, train F1: 61.9022 Val Loss: 1.5548, valid acc: 62.8346, valid F1: 62.8191
# Epoch 31, Train Loss: 1.4478, train acc: 62.0415, train F1: 62.0251 Val Loss: 1.5523, valid acc: 62.8346, valid F1: 62.8235
# Epoch 32, Train Loss: 1.4457, train acc: 62.0016, train F1: 61.9859 Val Loss: 1.5499, valid acc: 62.8346, valid F1: 62.8272
# Epoch 33, Train Loss: 1.4436, train acc: 62.0016, train F1: 61.9846 Val Loss: 1.5473, valid acc: 62.8346, valid F1: 62.8272
# Epoch 34, Train Loss: 1.4414, train acc: 61.8820, train F1: 61.8601 Val Loss: 1.5448, valid acc: 62.8346, valid F1: 62.8272
# Epoch 35, Train Loss: 1.4392, train acc: 61.8820, train F1: 61.8587 Val Loss: 1.5422, valid acc: 62.8346, valid F1: 62.8272
# Epoch 36, Train Loss: 1.4370, train acc: 61.9219, train F1: 61.8993 Val Loss: 1.5396, valid acc: 62.8346, valid F1: 62.8301
# Epoch 37, Train Loss: 1.4348, train acc: 62.0813, train F1: 62.0617 Val Loss: 1.5370, valid acc: 62.6772, valid F1: 62.6757
# Epoch 38, Train Loss: 1.4326, train acc: 62.1212, train F1: 62.0980 Val Loss: 1.5345, valid acc: 62.6772, valid F1: 62.6757
# Epoch 39, Train Loss: 1.4305, train acc: 62.2010, train F1: 62.1821 Val Loss: 1.5319, valid acc: 62.5197, valid F1: 62.5174
# Epoch 40, Train Loss: 1.4285, train acc: 62.1611, train F1: 62.1454 Val Loss: 1.5292, valid acc: 62.9921, valid F1: 62.9863
# Epoch 41, Train Loss: 1.4263, train acc: 62.2807, train F1: 62.2680 Val Loss: 1.5267, valid acc: 62.9921, valid F1: 62.9829
# Epoch 42, Train Loss: 1.4243, train acc: 62.3604, train F1: 62.3478 Val Loss: 1.5241, valid acc: 63.1496, valid F1: 63.1422
# Epoch 43, Train Loss: 1.4222, train acc: 62.5199, train F1: 62.5062 Val Loss: 1.5215, valid acc: 63.6220, valid F1: 63.6163
# Epoch 44, Train Loss: 1.4201, train acc: 62.4402, train F1: 62.4297 Val Loss: 1.5190, valid acc: 64.2520, valid F1: 64.2488
# Epoch 45, Train Loss: 1.4181, train acc: 62.3604, train F1: 62.3543 Val Loss: 1.5166, valid acc: 63.7795, valid F1: 63.7723
# Epoch 46, Train Loss: 1.4161, train acc: 62.3604, train F1: 62.3564 Val Loss: 1.5140, valid acc: 63.6220, valid F1: 63.6091
# Epoch 47, Train Loss: 1.4141, train acc: 62.1611, train F1: 62.1573 Val Loss: 1.5115, valid acc: 63.9370, valid F1: 63.9195
# Epoch 48, Train Loss: 1.4120, train acc: 62.2408, train F1: 62.2377 Val Loss: 1.5091, valid acc: 63.9370, valid F1: 63.9195
# Epoch 49, Train Loss: 1.4100, train acc: 62.1611, train F1: 62.1584 Val Loss: 1.5066, valid acc: 63.9370, valid F1: 63.9195
# Epoch 50, Train Loss: 1.4080, train acc: 62.2010, train F1: 62.1990 Val Loss: 1.5042, valid acc: 63.9370, valid F1: 63.9195
# Epoch 51, Train Loss: 1.4060, train acc: 62.2807, train F1: 62.2792 Val Loss: 1.5018, valid acc: 63.7795, valid F1: 63.7593
# Epoch 52, Train Loss: 1.4041, train acc: 62.3206, train F1: 62.3196 Val Loss: 1.4995, valid acc: 63.7795, valid F1: 63.7593
# Epoch 53, Train Loss: 1.4022, train acc: 62.5598, train F1: 62.5593 Val Loss: 1.4973, valid acc: 63.7795, valid F1: 63.7593
# Epoch 54, Train Loss: 1.4003, train acc: 62.6396, train F1: 62.6393 Val Loss: 1.4950, valid acc: 63.9370, valid F1: 63.9195
# Epoch 55, Train Loss: 1.3985, train acc: 62.7592, train F1: 62.7586 Val Loss: 1.4928, valid acc: 64.0945, valid F1: 64.0744
# Epoch 56, Train Loss: 1.3967, train acc: 62.8389, train F1: 62.8383 Val Loss: 1.4907, valid acc: 63.7795, valid F1: 63.7593
# Epoch 57, Train Loss: 1.3949, train acc: 62.9585, train F1: 62.9578 Val Loss: 1.4885, valid acc: 63.4646, valid F1: 63.4384
# Epoch 58, Train Loss: 1.3931, train acc: 62.9187, train F1: 62.9181 Val Loss: 1.4863, valid acc: 63.4646, valid F1: 63.4384
# Epoch 59, Train Loss: 1.3914, train acc: 62.9984, train F1: 62.9976 Val Loss: 1.4843, valid acc: 63.6220, valid F1: 63.5989
# Epoch 60, Train Loss: 1.3896, train acc: 63.0383, train F1: 63.0378 Val Loss: 1.4823, valid acc: 63.7795, valid F1: 63.7535
# Epoch 61, Train Loss: 1.3880, train acc: 62.9984, train F1: 62.9980 Val Loss: 1.4804, valid acc: 64.0945, valid F1: 64.0687
# Epoch 62, Train Loss: 1.3863, train acc: 62.9984, train F1: 62.9984 Val Loss: 1.4786, valid acc: 64.2520, valid F1: 64.2293
# Epoch 63, Train Loss: 1.3847, train acc: 62.9585, train F1: 62.9585 Val Loss: 1.4768, valid acc: 64.2520, valid F1: 64.2346
# Epoch 64, Train Loss: 1.3831, train acc: 62.9585, train F1: 62.9584 Val Loss: 1.4751, valid acc: 64.0945, valid F1: 64.0837
# Epoch 65, Train Loss: 1.3816, train acc: 62.8788, train F1: 62.8783 Val Loss: 1.4734, valid acc: 63.9370, valid F1: 63.9241
# Epoch 66, Train Loss: 1.3802, train acc: 62.9585, train F1: 62.9581 Val Loss: 1.4718, valid acc: 63.7795, valid F1: 63.7593
# Epoch 67, Train Loss: 1.3787, train acc: 62.9585, train F1: 62.9581 Val Loss: 1.4702, valid acc: 64.2520, valid F1: 64.2346
# Epoch 68, Train Loss: 1.3772, train acc: 62.9585, train F1: 62.9581 Val Loss: 1.4687, valid acc: 64.5669, valid F1: 64.5444
# Epoch 69, Train Loss: 1.3759, train acc: 62.9187, train F1: 62.9183 Val Loss: 1.4671, valid acc: 64.4094, valid F1: 64.3896
# Epoch 70, Train Loss: 1.3745, train acc: 63.1180, train F1: 63.1175 Val Loss: 1.4657, valid acc: 64.4094, valid F1: 64.3896
# Epoch 71, Train Loss: 1.3733, train acc: 63.1579, train F1: 63.1575 Val Loss: 1.4643, valid acc: 64.4094, valid F1: 64.3896
# Epoch 72, Train Loss: 1.3720, train acc: 63.1180, train F1: 63.1175 Val Loss: 1.4630, valid acc: 64.5669, valid F1: 64.5497
# Epoch 73, Train Loss: 1.3708, train acc: 63.1579, train F1: 63.1575 Val Loss: 1.4616, valid acc: 64.2520, valid F1: 64.2346
# Epoch 74, Train Loss: 1.3696, train acc: 63.1978, train F1: 63.1975 Val Loss: 1.4604, valid acc: 64.2520, valid F1: 64.2346
# Epoch 75, Train Loss: 1.3685, train acc: 63.1180, train F1: 63.1173 Val Loss: 1.4592, valid acc: 64.2520, valid F1: 64.2392
# Epoch 76, Train Loss: 1.3673, train acc: 62.9984, train F1: 62.9980 Val Loss: 1.4579, valid acc: 64.2520, valid F1: 64.2346
# Epoch 77, Train Loss: 1.3662, train acc: 62.9585, train F1: 62.9578 Val Loss: 1.4566, valid acc: 64.4094, valid F1: 64.3945
# Epoch 78, Train Loss: 1.3651, train acc: 63.0383, train F1: 63.0376 Val Loss: 1.4554, valid acc: 64.5669, valid F1: 64.5497
# Epoch 79, Train Loss: 1.3641, train acc: 63.1978, train F1: 63.1968 Val Loss: 1.4544, valid acc: 64.4094, valid F1: 64.3945
# Epoch 80, Train Loss: 1.3631, train acc: 63.1579, train F1: 63.1571 Val Loss: 1.4532, valid acc: 64.4094, valid F1: 64.3945
# Epoch 81, Train Loss: 1.3620, train acc: 63.3174, train F1: 63.3168 Val Loss: 1.4521, valid acc: 64.5669, valid F1: 64.5497
# Epoch 82, Train Loss: 1.3611, train acc: 63.4769, train F1: 63.4760 Val Loss: 1.4511, valid acc: 64.0945, valid F1: 64.0794
# Epoch 83, Train Loss: 1.3601, train acc: 63.6762, train F1: 63.6746 Val Loss: 1.4501, valid acc: 64.8819, valid F1: 64.8693
# Epoch 84, Train Loss: 1.3593, train acc: 63.7959, train F1: 63.7920 Val Loss: 1.4491, valid acc: 65.3543, valid F1: 65.3501
# Epoch 85, Train Loss: 1.3583, train acc: 63.7161, train F1: 63.7116 Val Loss: 1.4481, valid acc: 65.6693, valid F1: 65.6624
# Epoch 86, Train Loss: 1.3575, train acc: 63.7161, train F1: 63.7109 Val Loss: 1.4472, valid acc: 65.8268, valid F1: 65.8213
# Epoch 87, Train Loss: 1.3566, train acc: 63.7959, train F1: 63.7900 Val Loss: 1.4463, valid acc: 65.8268, valid F1: 65.8213
# Epoch 88, Train Loss: 1.3558, train acc: 63.6364, train F1: 63.6304 Val Loss: 1.4454, valid acc: 65.6693, valid F1: 65.6624
# Epoch 89, Train Loss: 1.3550, train acc: 63.5566, train F1: 63.5521 Val Loss: 1.4446, valid acc: 65.6693, valid F1: 65.6624
# Epoch 90, Train Loss: 1.3542, train acc: 63.5566, train F1: 63.5527 Val Loss: 1.4438, valid acc: 65.8268, valid F1: 65.8183
# Epoch 91, Train Loss: 1.3534, train acc: 63.6762, train F1: 63.6714 Val Loss: 1.4430, valid acc: 65.8268, valid F1: 65.8183
# Epoch 92, Train Loss: 1.3527, train acc: 63.7161, train F1: 63.7116 Val Loss: 1.4423, valid acc: 65.8268, valid F1: 65.8183
# Epoch 93, Train Loss: 1.3520, train acc: 63.7560, train F1: 63.7518 Val Loss: 1.4415, valid acc: 65.8268, valid F1: 65.8183
# Epoch 94, Train Loss: 1.3512, train acc: 63.7959, train F1: 63.7913 Val Loss: 1.4408, valid acc: 65.6693, valid F1: 65.6590
# Epoch 95, Train Loss: 1.3506, train acc: 63.7560, train F1: 63.7529 Val Loss: 1.4402, valid acc: 65.8268, valid F1: 65.8146
# Epoch 96, Train Loss: 1.3498, train acc: 63.7161, train F1: 63.7133 Val Loss: 1.4395, valid acc: 65.6693, valid F1: 65.6590
# Epoch 97, Train Loss: 1.3492, train acc: 63.7161, train F1: 63.7133 Val Loss: 1.4388, valid acc: 65.8268, valid F1: 65.8146
# Epoch 98, Train Loss: 1.3485, train acc: 63.8357, train F1: 63.8337 Val Loss: 1.4382, valid acc: 65.8268, valid F1: 65.8146
# Epoch 99, Train Loss: 1.3479, train acc: 63.8756, train F1: 63.8741 Val Loss: 1.4376, valid acc: 65.8268, valid F1: 65.8146
# Epoch 100, Train Loss: 1.3473, train acc: 63.8756, train F1: 63.8741 Val Loss: 1.4370, valid acc: 65.8268, valid F1: 65.8146
# Epoch 101, Train Loss: 1.3467, train acc: 63.8357, train F1: 63.8341 Val Loss: 1.4364, valid acc: 65.8268, valid F1: 65.8146
# Epoch 102, Train Loss: 1.3461, train acc: 63.8357, train F1: 63.8341 Val Loss: 1.4359, valid acc: 65.6693, valid F1: 65.6549
# Epoch 103, Train Loss: 1.3455, train acc: 63.8756, train F1: 63.8741 Val Loss: 1.4353, valid acc: 65.8268, valid F1: 65.8146
# Epoch 104, Train Loss: 1.3449, train acc: 63.8756, train F1: 63.8741 Val Loss: 1.4347, valid acc: 65.5118, valid F1: 65.4950
# Epoch 105, Train Loss: 1.3444, train acc: 63.9155, train F1: 63.9145 Val Loss: 1.4342, valid acc: 65.6693, valid F1: 65.6501
# Epoch 106, Train Loss: 1.3438, train acc: 63.9155, train F1: 63.9145 Val Loss: 1.4337, valid acc: 65.6693, valid F1: 65.6501
# Epoch 107, Train Loss: 1.3433, train acc: 63.9553, train F1: 63.9545 Val Loss: 1.4333, valid acc: 65.6693, valid F1: 65.6501
# Epoch 108, Train Loss: 1.3428, train acc: 63.9155, train F1: 63.9150 Val Loss: 1.4328, valid acc: 65.6693, valid F1: 65.6501
# Epoch 109, Train Loss: 1.3423, train acc: 63.8756, train F1: 63.8754 Val Loss: 1.4324, valid acc: 65.6693, valid F1: 65.6501
# Epoch 110, Train Loss: 1.3418, train acc: 63.8756, train F1: 63.8752 Val Loss: 1.4320, valid acc: 65.6693, valid F1: 65.6501
# Epoch 111, Train Loss: 1.3413, train acc: 64.0351, train F1: 64.0350 Val Loss: 1.4316, valid acc: 65.6693, valid F1: 65.6501
# Epoch 112, Train Loss: 1.3408, train acc: 63.9952, train F1: 63.9952 Val Loss: 1.4312, valid acc: 65.6693, valid F1: 65.6501
# Epoch 113, Train Loss: 1.3404, train acc: 64.1946, train F1: 64.1946 Val Loss: 1.4309, valid acc: 65.6693, valid F1: 65.6501
# Epoch 114, Train Loss: 1.3399, train acc: 64.1946, train F1: 64.1946 Val Loss: 1.4305, valid acc: 65.6693, valid F1: 65.6501
# Epoch 115, Train Loss: 1.3395, train acc: 64.2344, train F1: 64.2344 Val Loss: 1.4302, valid acc: 65.6693, valid F1: 65.6501
# Epoch 116, Train Loss: 1.3391, train acc: 64.2344, train F1: 64.2344 Val Loss: 1.4298, valid acc: 65.6693, valid F1: 65.6501
# Epoch 117, Train Loss: 1.3387, train acc: 64.2344, train F1: 64.2344 Val Loss: 1.4295, valid acc: 65.8268, valid F1: 65.8051
# Epoch 118, Train Loss: 1.3383, train acc: 64.2743, train F1: 64.2743 Val Loss: 1.4292, valid acc: 65.9843, valid F1: 65.9653
# Epoch 119, Train Loss: 1.3379, train acc: 64.3142, train F1: 64.3142 Val Loss: 1.4289, valid acc: 66.1417, valid F1: 66.1253
# Epoch 120, Train Loss: 1.3375, train acc: 64.3142, train F1: 64.3142 Val Loss: 1.4286, valid acc: 66.1417, valid F1: 66.1253
# Epoch 121, Train Loss: 1.3371, train acc: 64.2743, train F1: 64.2743 Val Loss: 1.4284, valid acc: 66.2992, valid F1: 66.2851
# Epoch 122, Train Loss: 1.3368, train acc: 64.3541, train F1: 64.3541 Val Loss: 1.4280, valid acc: 66.2992, valid F1: 66.2851
# Epoch 123, Train Loss: 1.3364, train acc: 64.3541, train F1: 64.3541 Val Loss: 1.4278, valid acc: 66.2992, valid F1: 66.2851
# Epoch 124, Train Loss: 1.3361, train acc: 64.5136, train F1: 64.5135 Val Loss: 1.4275, valid acc: 66.1417, valid F1: 66.1296
# Epoch 125, Train Loss: 1.3357, train acc: 64.5136, train F1: 64.5135 Val Loss: 1.4273, valid acc: 65.9843, valid F1: 65.9740
# Epoch 126, Train Loss: 1.3354, train acc: 64.4737, train F1: 64.4736 Val Loss: 1.4270, valid acc: 65.8268, valid F1: 65.8146
# Epoch 127, Train Loss: 1.3351, train acc: 64.3541, train F1: 64.3540 Val Loss: 1.4269, valid acc: 65.8268, valid F1: 65.8146
# Epoch 128, Train Loss: 1.3348, train acc: 64.3541, train F1: 64.3540 Val Loss: 1.4266, valid acc: 65.8268, valid F1: 65.8146
# Epoch 129, Train Loss: 1.3345, train acc: 64.3939, train F1: 64.3939 Val Loss: 1.4264, valid acc: 65.9843, valid F1: 65.9740
# Epoch 130, Train Loss: 1.3342, train acc: 64.4737, train F1: 64.4735 Val Loss: 1.4262, valid acc: 65.9843, valid F1: 65.9740
# Epoch 131, Train Loss: 1.3339, train acc: 64.3541, train F1: 64.3540 Val Loss: 1.4260, valid acc: 65.9843, valid F1: 65.9740
# Epoch 132, Train Loss: 1.3337, train acc: 64.3541, train F1: 64.3540 Val Loss: 1.4258, valid acc: 65.9843, valid F1: 65.9740
# Epoch 133, Train Loss: 1.3334, train acc: 64.4737, train F1: 64.4736 Val Loss: 1.4256, valid acc: 65.9843, valid F1: 65.9740
# Epoch 134, Train Loss: 1.3331, train acc: 64.5136, train F1: 64.5135 Val Loss: 1.4254, valid acc: 65.9843, valid F1: 65.9740
# Epoch 135, Train Loss: 1.3329, train acc: 64.5534, train F1: 64.5532 Val Loss: 1.4253, valid acc: 65.9843, valid F1: 65.9740
# Epoch 136, Train Loss: 1.3327, train acc: 64.5534, train F1: 64.5527 Val Loss: 1.4251, valid acc: 65.8268, valid F1: 65.8183
# Epoch 137, Train Loss: 1.3324, train acc: 64.4737, train F1: 64.4727 Val Loss: 1.4250, valid acc: 66.1417, valid F1: 66.1333
# Epoch 138, Train Loss: 1.3321, train acc: 64.4737, train F1: 64.4727 Val Loss: 1.4248, valid acc: 66.1417, valid F1: 66.1333
# Epoch 139, Train Loss: 1.3319, train acc: 64.3939, train F1: 64.3930 Val Loss: 1.4246, valid acc: 66.1417, valid F1: 66.1333
# Epoch 140, Train Loss: 1.3317, train acc: 64.3142, train F1: 64.3132 Val Loss: 1.4245, valid acc: 66.1417, valid F1: 66.1333
# Epoch 141, Train Loss: 1.3314, train acc: 64.4338, train F1: 64.4327 Val Loss: 1.4244, valid acc: 66.1417, valid F1: 66.1333
# Epoch 142, Train Loss: 1.3312, train acc: 64.3142, train F1: 64.3132 Val Loss: 1.4242, valid acc: 66.1417, valid F1: 66.1333
# Epoch 143, Train Loss: 1.3310, train acc: 64.3939, train F1: 64.3927 Val Loss: 1.4241, valid acc: 66.1417, valid F1: 66.1333
# Epoch 144, Train Loss: 1.3308, train acc: 64.3939, train F1: 64.3927 Val Loss: 1.4239, valid acc: 66.1417, valid F1: 66.1333
# Epoch 145, Train Loss: 1.3306, train acc: 64.5136, train F1: 64.5125 Val Loss: 1.4238, valid acc: 66.2992, valid F1: 66.2924
# Epoch 146, Train Loss: 1.3303, train acc: 64.4737, train F1: 64.4724 Val Loss: 1.4236, valid acc: 66.2992, valid F1: 66.2924
# Epoch 147, Train Loss: 1.3301, train acc: 64.4338, train F1: 64.4327 Val Loss: 1.4235, valid acc: 66.1417, valid F1: 66.1364
# Epoch 148, Train Loss: 1.3300, train acc: 64.3939, train F1: 64.3927 Val Loss: 1.4235, valid acc: 65.9843, valid F1: 65.9774
# Epoch 149, Train Loss: 1.3298, train acc: 64.3142, train F1: 64.3121 Val Loss: 1.4233, valid acc: 66.1417, valid F1: 66.1333
# Epoch 150, Train Loss: 1.3296, train acc: 64.3142, train F1: 64.3121 Val Loss: 1.4232, valid acc: 66.1417, valid F1: 66.1333
# Epoch 151, Train Loss: 1.3294, train acc: 64.3541, train F1: 64.3513 Val Loss: 1.4232, valid acc: 65.9843, valid F1: 65.9774
# Epoch 152, Train Loss: 1.3292, train acc: 64.3939, train F1: 64.3909 Val Loss: 1.4230, valid acc: 65.9843, valid F1: 65.9774
# Epoch 153, Train Loss: 1.3290, train acc: 64.4338, train F1: 64.4306 Val Loss: 1.4229, valid acc: 65.9843, valid F1: 65.9774
# Epoch 154, Train Loss: 1.3289, train acc: 64.4338, train F1: 64.4306 Val Loss: 1.4228, valid acc: 65.9843, valid F1: 65.9801
# Epoch 155, Train Loss: 1.3287, train acc: 64.4737, train F1: 64.4707 Val Loss: 1.4227, valid acc: 65.8268, valid F1: 65.8237
# Epoch 156, Train Loss: 1.3285, train acc: 64.4737, train F1: 64.4707 Val Loss: 1.4227, valid acc: 65.9843, valid F1: 65.9801
# Epoch 157, Train Loss: 1.3284, train acc: 64.4338, train F1: 64.4306 Val Loss: 1.4226, valid acc: 65.9843, valid F1: 65.9821
# Epoch 158, Train Loss: 1.3282, train acc: 64.3939, train F1: 64.3904 Val Loss: 1.4226, valid acc: 65.9843, valid F1: 65.9821
# Epoch 159, Train Loss: 1.3280, train acc: 64.3939, train F1: 64.3898 Val Loss: 1.4225, valid acc: 66.1417, valid F1: 66.1387
# Epoch 160, Train Loss: 1.3279, train acc: 64.3939, train F1: 64.3898 Val Loss: 1.4224, valid acc: 66.1417, valid F1: 66.1387
# Epoch 161, Train Loss: 1.3277, train acc: 64.3541, train F1: 64.3496 Val Loss: 1.4223, valid acc: 66.1417, valid F1: 66.1387
# Epoch 162, Train Loss: 1.3276, train acc: 64.2743, train F1: 64.2699 Val Loss: 1.4223, valid acc: 65.9843, valid F1: 65.9821
# Epoch 163, Train Loss: 1.3274, train acc: 64.3939, train F1: 64.3892 Val Loss: 1.4222, valid acc: 66.1417, valid F1: 66.1387
# Epoch 164, Train Loss: 1.3273, train acc: 64.3541, train F1: 64.3496 Val Loss: 1.4222, valid acc: 66.1417, valid F1: 66.1387
# Epoch 165, Train Loss: 1.3272, train acc: 64.3142, train F1: 64.3080 Val Loss: 1.4222, valid acc: 66.1417, valid F1: 66.1387
# Epoch 166, Train Loss: 1.3270, train acc: 64.4737, train F1: 64.4668 Val Loss: 1.4221, valid acc: 66.1417, valid F1: 66.1387
# Epoch 167, Train Loss: 1.3269, train acc: 64.3541, train F1: 64.3475 Val Loss: 1.4220, valid acc: 66.1417, valid F1: 66.1387
# Epoch 168, Train Loss: 1.3268, train acc: 64.3939, train F1: 64.3870 Val Loss: 1.4220, valid acc: 66.1417, valid F1: 66.1387
# Epoch 169, Train Loss: 1.3266, train acc: 64.3939, train F1: 64.3870 Val Loss: 1.4220, valid acc: 66.1417, valid F1: 66.1387
# Epoch 170, Train Loss: 1.3265, train acc: 64.3939, train F1: 64.3870 Val Loss: 1.4219, valid acc: 66.1417, valid F1: 66.1387
# Epoch 171, Train Loss: 1.3264, train acc: 64.4338, train F1: 64.4265 Val Loss: 1.4219, valid acc: 66.6142, valid F1: 66.6101
# Epoch 172, Train Loss: 1.3263, train acc: 64.4338, train F1: 64.4265 Val Loss: 1.4219, valid acc: 66.6142, valid F1: 66.6101
# Epoch 173, Train Loss: 1.3261, train acc: 64.4338, train F1: 64.4265 Val Loss: 1.4218, valid acc: 66.6142, valid F1: 66.6101
# Epoch 174, Train Loss: 1.3260, train acc: 64.3939, train F1: 64.3870 Val Loss: 1.4217, valid acc: 66.6142, valid F1: 66.6101
# Epoch 175, Train Loss: 1.3259, train acc: 64.4338, train F1: 64.4265 Val Loss: 1.4217, valid acc: 66.7717, valid F1: 66.7687
# Epoch 176, Train Loss: 1.3258, train acc: 64.3939, train F1: 64.3862 Val Loss: 1.4216, valid acc: 66.7717, valid F1: 66.7687
# Epoch 177, Train Loss: 1.3257, train acc: 64.3939, train F1: 64.3862 Val Loss: 1.4216, valid acc: 66.7717, valid F1: 66.7687
# Epoch 178, Train Loss: 1.3256, train acc: 64.3541, train F1: 64.3467 Val Loss: 1.4216, valid acc: 66.7717, valid F1: 66.7687
# Epoch 179, Train Loss: 1.3255, train acc: 64.3939, train F1: 64.3853 Val Loss: 1.4216, valid acc: 66.7717, valid F1: 66.7687
# Epoch 180, Train Loss: 1.3254, train acc: 64.3541, train F1: 64.3459 Val Loss: 1.4215, valid acc: 66.7717, valid F1: 66.7687
# Epoch 181, Train Loss: 1.3252, train acc: 64.3541, train F1: 64.3450 Val Loss: 1.4214, valid acc: 66.7717, valid F1: 66.7687
# Epoch 182, Train Loss: 1.3252, train acc: 64.3939, train F1: 64.3853 Val Loss: 1.4214, valid acc: 66.7717, valid F1: 66.7687
# Epoch 183, Train Loss: 1.3250, train acc: 64.4338, train F1: 64.4256 Val Loss: 1.4214, valid acc: 66.7717, valid F1: 66.7687
# Epoch 184, Train Loss: 1.3249, train acc: 64.4338, train F1: 64.4256 Val Loss: 1.4214, valid acc: 66.7717, valid F1: 66.7687
# Epoch 185, Train Loss: 1.3248, train acc: 64.4338, train F1: 64.4256 Val Loss: 1.4213, valid acc: 66.7717, valid F1: 66.7687
# Epoch 186, Train Loss: 1.3247, train acc: 64.3939, train F1: 64.3853 Val Loss: 1.4213, valid acc: 66.7717, valid F1: 66.7687
# Epoch 187, Train Loss: 1.3246, train acc: 64.3142, train F1: 64.3047 Val Loss: 1.4213, valid acc: 66.7717, valid F1: 66.7687
# Epoch 188, Train Loss: 1.3245, train acc: 64.3142, train F1: 64.3047 Val Loss: 1.4212, valid acc: 66.7717, valid F1: 66.7687
# Epoch 189, Train Loss: 1.3244, train acc: 64.4338, train F1: 64.4238 Val Loss: 1.4212, valid acc: 66.7717, valid F1: 66.7687
# Epoch 190, Train Loss: 1.3243, train acc: 64.4338, train F1: 64.4229 Val Loss: 1.4211, valid acc: 66.7717, valid F1: 66.7687
# Epoch 191, Train Loss: 1.3243, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4211, valid acc: 66.4567, valid F1: 66.4537
# Epoch 192, Train Loss: 1.3242, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4211, valid acc: 66.4567, valid F1: 66.4537
# Epoch 193, Train Loss: 1.3241, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4210, valid acc: 66.4567, valid F1: 66.4537
# Epoch 194, Train Loss: 1.3240, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4210, valid acc: 66.6142, valid F1: 66.6121
# Epoch 195, Train Loss: 1.3239, train acc: 64.4338, train F1: 64.4229 Val Loss: 1.4210, valid acc: 66.4567, valid F1: 66.4537
# Epoch 196, Train Loss: 1.3238, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4210, valid acc: 66.6142, valid F1: 66.6121
# Epoch 197, Train Loss: 1.3237, train acc: 64.3541, train F1: 64.3421 Val Loss: 1.4210, valid acc: 66.2992, valid F1: 66.2971
# Epoch 198, Train Loss: 1.3236, train acc: 64.4338, train F1: 64.4218 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 199, Train Loss: 1.3236, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 66.2992, valid F1: 66.2971
# Epoch 200, Train Loss: 1.3235, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 66.2992, valid F1: 66.2971
# Epoch 201, Train Loss: 1.3234, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 202, Train Loss: 1.3233, train acc: 64.4338, train F1: 64.4218 Val Loss: 1.4210, valid acc: 66.2992, valid F1: 66.2971
# Epoch 203, Train Loss: 1.3232, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 66.2992, valid F1: 66.2971
# Epoch 204, Train Loss: 1.3232, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 205, Train Loss: 1.3231, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 206, Train Loss: 1.3230, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 207, Train Loss: 1.3229, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 208, Train Loss: 1.3229, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.4567, valid F1: 66.4537
# Epoch 209, Train Loss: 1.3228, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 210, Train Loss: 1.3227, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.2992, valid F1: 66.2951
# Epoch 211, Train Loss: 1.3227, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1387
# Epoch 212, Train Loss: 1.3226, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2951
# Epoch 213, Train Loss: 1.3225, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1387
# Epoch 214, Train Loss: 1.3224, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 215, Train Loss: 1.3224, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 216, Train Loss: 1.3223, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 217, Train Loss: 1.3222, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 218, Train Loss: 1.3221, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 219, Train Loss: 1.3221, train acc: 64.5933, train F1: 64.5834 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 220, Train Loss: 1.3220, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 221, Train Loss: 1.3219, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4207, valid acc: 66.1417, valid F1: 66.1387
# Epoch 222, Train Loss: 1.3219, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 223, Train Loss: 1.3218, train acc: 64.5933, train F1: 64.5834 Val Loss: 1.4207, valid acc: 66.1417, valid F1: 66.1387
# Epoch 224, Train Loss: 1.3217, train acc: 64.5933, train F1: 64.5834 Val Loss: 1.4207, valid acc: 66.1417, valid F1: 66.1387
# Epoch 225, Train Loss: 1.3217, train acc: 64.5933, train F1: 64.5834 Val Loss: 1.4207, valid acc: 66.1417, valid F1: 66.1387
# Epoch 226, Train Loss: 1.3216, train acc: 64.5933, train F1: 64.5834 Val Loss: 1.4207, valid acc: 66.1417, valid F1: 66.1387
# Epoch 227, Train Loss: 1.3215, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 228, Train Loss: 1.3215, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 229, Train Loss: 1.3214, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 230, Train Loss: 1.3213, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 231, Train Loss: 1.3213, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 232, Train Loss: 1.3212, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 233, Train Loss: 1.3212, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4208, valid acc: 66.1417, valid F1: 66.1387
# Epoch 234, Train Loss: 1.3211, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4208, valid acc: 66.2992, valid F1: 66.2971
# Epoch 235, Train Loss: 1.3210, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4208, valid acc: 66.2992, valid F1: 66.2971
# Epoch 236, Train Loss: 1.3210, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 237, Train Loss: 1.3209, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 238, Train Loss: 1.3209, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 239, Train Loss: 1.3208, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 240, Train Loss: 1.3207, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 241, Train Loss: 1.3207, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 242, Train Loss: 1.3206, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4209, valid acc: 66.2992, valid F1: 66.2971
# Epoch 243, Train Loss: 1.3206, train acc: 64.5136, train F1: 64.5036 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 244, Train Loss: 1.3205, train acc: 64.5136, train F1: 64.5036 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 245, Train Loss: 1.3205, train acc: 64.5136, train F1: 64.5036 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 246, Train Loss: 1.3204, train acc: 64.4737, train F1: 64.4632 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 247, Train Loss: 1.3203, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4210, valid acc: 66.1417, valid F1: 66.1404
# Epoch 248, Train Loss: 1.3203, train acc: 64.4737, train F1: 64.4632 Val Loss: 1.4209, valid acc: 66.1417, valid F1: 66.1404
# Epoch 249, Train Loss: 1.3202, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4210, valid acc: 66.1417, valid F1: 66.1404
# Epoch 250, Train Loss: 1.3202, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 66.1417, valid F1: 66.1404
# Epoch 251, Train Loss: 1.3201, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 252, Train Loss: 1.3200, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 253, Train Loss: 1.3200, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 254, Train Loss: 1.3199, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 255, Train Loss: 1.3199, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 256, Train Loss: 1.3198, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 257, Train Loss: 1.3198, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 258, Train Loss: 1.3197, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 259, Train Loss: 1.3197, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 260, Train Loss: 1.3196, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 261, Train Loss: 1.3195, train acc: 64.4737, train F1: 64.4612 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 262, Train Loss: 1.3195, train acc: 64.4338, train F1: 64.4218 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 263, Train Loss: 1.3194, train acc: 64.3541, train F1: 64.3421 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 264, Train Loss: 1.3194, train acc: 64.3541, train F1: 64.3421 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 265, Train Loss: 1.3193, train acc: 64.3541, train F1: 64.3421 Val Loss: 1.4210, valid acc: 65.9843, valid F1: 65.9821
# Epoch 266, Train Loss: 1.3193, train acc: 64.3541, train F1: 64.3421 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 267, Train Loss: 1.3192, train acc: 64.3939, train F1: 64.3814 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 268, Train Loss: 1.3192, train acc: 64.5136, train F1: 64.5016 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 269, Train Loss: 1.3191, train acc: 64.4338, train F1: 64.4218 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 270, Train Loss: 1.3190, train acc: 64.4737, train F1: 64.4612 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 271, Train Loss: 1.3190, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 272, Train Loss: 1.3189, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 273, Train Loss: 1.3189, train acc: 64.5933, train F1: 64.5824 Val Loss: 1.4211, valid acc: 65.9843, valid F1: 65.9821
# Epoch 274, Train Loss: 1.3188, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4211, valid acc: 66.1417, valid F1: 66.1404
# Epoch 275, Train Loss: 1.3188, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4211, valid acc: 66.1417, valid F1: 66.1387
# Epoch 276, Train Loss: 1.3187, train acc: 64.4737, train F1: 64.4622 Val Loss: 1.4211, valid acc: 66.2992, valid F1: 66.2971
# Epoch 277, Train Loss: 1.3187, train acc: 64.5136, train F1: 64.5026 Val Loss: 1.4211, valid acc: 66.2992, valid F1: 66.2971
# Epoch 278, Train Loss: 1.3186, train acc: 64.5534, train F1: 64.5420 Val Loss: 1.4211, valid acc: 66.2992, valid F1: 66.2971
# Epoch 279, Train Loss: 1.3186, train acc: 64.5136, train F1: 64.5036 Val Loss: 1.4211, valid acc: 66.2992, valid F1: 66.2971
# Epoch 280, Train Loss: 1.3185, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4211, valid acc: 66.2992, valid F1: 66.2971
# Epoch 281, Train Loss: 1.3185, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4212, valid acc: 66.2992, valid F1: 66.2971
# Epoch 282, Train Loss: 1.3184, train acc: 64.5136, train F1: 64.5036 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 283, Train Loss: 1.3183, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 284, Train Loss: 1.3183, train acc: 64.5534, train F1: 64.5430 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 285, Train Loss: 1.3182, train acc: 64.5534, train F1: 64.5440 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 286, Train Loss: 1.3182, train acc: 64.5534, train F1: 64.5440 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 287, Train Loss: 1.3181, train acc: 64.5534, train F1: 64.5440 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 288, Train Loss: 1.3181, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 289, Train Loss: 1.3180, train acc: 64.5534, train F1: 64.5440 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 290, Train Loss: 1.3180, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 291, Train Loss: 1.3179, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4212, valid acc: 66.4567, valid F1: 66.4537
# Epoch 292, Train Loss: 1.3179, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 293, Train Loss: 1.3178, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 294, Train Loss: 1.3177, train acc: 64.5933, train F1: 64.5843 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 295, Train Loss: 1.3177, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 296, Train Loss: 1.3176, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 297, Train Loss: 1.3176, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 298, Train Loss: 1.3175, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 299, Train Loss: 1.3175, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 300, Train Loss: 1.3174, train acc: 64.6730, train F1: 64.6641 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 301, Train Loss: 1.3174, train acc: 64.6730, train F1: 64.6641 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 302, Train Loss: 1.3173, train acc: 64.6730, train F1: 64.6641 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 303, Train Loss: 1.3173, train acc: 64.6730, train F1: 64.6641 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 304, Train Loss: 1.3172, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 305, Train Loss: 1.3172, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4213, valid acc: 66.4567, valid F1: 66.4537
# Epoch 306, Train Loss: 1.3171, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 307, Train Loss: 1.3171, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 308, Train Loss: 1.3170, train acc: 64.6332, train F1: 64.6237 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 309, Train Loss: 1.3169, train acc: 64.6730, train F1: 64.6631 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 310, Train Loss: 1.3169, train acc: 64.6730, train F1: 64.6631 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 311, Train Loss: 1.3168, train acc: 64.6730, train F1: 64.6631 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 312, Train Loss: 1.3168, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 313, Train Loss: 1.3167, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 314, Train Loss: 1.3167, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 315, Train Loss: 1.3166, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 316, Train Loss: 1.3166, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 317, Train Loss: 1.3165, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 318, Train Loss: 1.3164, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 319, Train Loss: 1.3164, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 320, Train Loss: 1.3163, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.4567, valid F1: 66.4537
# Epoch 321, Train Loss: 1.3163, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 322, Train Loss: 1.3162, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 323, Train Loss: 1.3162, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 324, Train Loss: 1.3161, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.2992, valid F1: 66.2951
# Epoch 325, Train Loss: 1.3161, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.1417, valid F1: 66.1387
# Epoch 326, Train Loss: 1.3160, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 327, Train Loss: 1.3159, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.1417, valid F1: 66.1387
# Epoch 328, Train Loss: 1.3159, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4214, valid acc: 66.1417, valid F1: 66.1387
# Epoch 329, Train Loss: 1.3158, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 330, Train Loss: 1.3158, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 331, Train Loss: 1.3157, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 332, Train Loss: 1.3157, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 333, Train Loss: 1.3156, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 334, Train Loss: 1.3155, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# Epoch 335, Train Loss: 1.3155, train acc: 64.7129, train F1: 64.7025 Val Loss: 1.4215, valid acc: 66.1417, valid F1: 66.1387
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 129
#     126     writer.close()
#     128 # Assuming train_loader and validation_loader are defined
# --> 129 train_model(image_user_sim_model, train_loader, test_loader, criterion, optimizer, epochs=n_epoch)
#
# Cell In[25], line 41, in train_model(model, train_loader, validation_loader, criterion, optimizer, epochs)
#      38 optimizer.zero_grad()
#      39 # print(batch_imageA_features.shape, batch_userGender.shape)
#      40 # forward + backward + optimize
# ---> 41 sim_A = model(
#      42     batch_imageA_features.to(device),
#      43     batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
#      44 )
#      45 sim_B = model(
#      46     batch_imageB_features.to(device),
#      47     batch_userGender.to(device), batch_userAgeIds.to(device), batch_userPrefectureIds.to(device)
#      48 )
#      50 # print('sim_A', sim_A, sim_A.shape)
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[11], line 12, in ImageUserSimilarityModel.forward(self, image_features, userGender, userAgeIds, userPrefectureIds)
#      10 def forward(self, image_features,  userGender, userAgeIds , userPrefectureIds):
#      11     # Process image features, expected shape should be (bs, 768)
# ---> 12     image_output = self.image_mlp(image_features)
#      14     # Process user attributes, expected shape should be (bs, 1)
#      15     user_embedded = self.user_embeddings(userGender, userAgeIds , userPrefectureIds)
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[9], line 21, in MLP.forward(self, x)
#      18     x = F.relu(layer(x))
#      20 # Output layer without ReLU
# ---> 21 x = self.layers[-1](x)
#      22 return x
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /mnt/g/yuan/venv/pyds/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
#save model weights
torch.save(image_user_sim_model.state_dict(), f'save/image_user_sim_model_bs{batch_size}_ep{n_epoch}_lr{lr}_hs{hidden_size}_os{output_size}.pth')

# %% [markdown]
# # test model performance

# %%
i = 3100
print(df_user.iloc[i, :])
image_id_A = df_user.iloc[i, :].Afilename
image_id_B = df_user.iloc[i, :].Bfilename
user_id = i
test_image_feature_A = torch.load(f'../features_from_samples_ly/image_feature/image_embeds_{image_id_A}_all.pt')
test_image_feature_B = torch.load(f'../features_from_samples_ly/image_feature/image_embeds_{image_id_B}_all.pt')

print(test_image_feature.shape)

test_userGender = user_data_dict['userGender'][user_id:user_id+1]# .unsqueeze(1)
test_userAgeIds = user_data_dict['userAgeIds'][user_id:user_id+1]# .unsqueeze(1)
test_userPrefectureIds = user_data_dict['userPrefectureIds'][user_id:user_id+1]# .unsqueeze(1)
print(test_userGender, test_userAgeIds, test_userPrefectureIds)

sim_A = image_user_sim_model(test_image_feature_A.to(device), test_userGender.to(device), test_userAgeIds.to(device), test_userPrefectureIds.to(device))
sim_B = image_user_sim_model(test_image_feature_B.to(device), test_userGender.to(device), test_userAgeIds.to(device), test_userPrefectureIds.to(device))
Q_pred = (sim_B.item() - sim_A.item())
print(sim_A.item(), sim_B.item(), Q_pred, )
# Out:
# Afilename            D_60
# Bfilename            C_26
# userGender              0
# userAgeIds             10
# userPrefectureIds      19
# userAddressIds        711
# Q1                    0.0
# Q_label                 2
# Name: 3100, dtype: object
# torch.Size([1, 768])
# tensor([[0]]) tensor([[10]]) tensor([[19]])
# -0.42924386262893677 -0.05177712440490723 0.37746673822402954
